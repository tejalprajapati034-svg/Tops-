# %% [markdown]
# # Introduction to Python

# %% [markdown]
# 1. Explain Python’s Role in Data Science

# %% [markdown]
# Python is the most popular programming language in data science due to its simplicity, flexibility, and huge ecosystem of libraries
#
# #Key Roles of Python in Data Science
#
#
# a . Data Collection
#
# b . Data Cleaning & Preparation
#
# c . Data Exploration & Visualization
#
# d . Machine Learning & AI
#
# e . Deployment & Automation
#
# f . Community & Ecosystem

# %% [markdown]
# 2Presentation: Object-Oriented Programming (OOP) Concepts in Python

# %% [markdown]
# Slide 1: Title Slide,
# Slide 2: Introduction,
# Slide 3: Key Principles of OOP,
# Slide 4: Class and Object,
# Slide 5: Encapsulation,
# Slide 6: Abstraction,
# Slide 7: Inheritance,
# Slide 8: Polymorphism,
# Slide 9: Benefits of OOP in Python,
# Slide 10: Conclusion

# %% [markdown]
# 1. Write a python program to sum of the first n positive integers.

# %%
num = int(input("Enter your number"))
total = 0 

for i in range (1 , num + 1):
    total += i 

print(f"Sum of first {num} positive integers is: {total}")
# Out:
# Sum of first 8 positive integers is: 36

# %% [markdown]
# 2. Write a Python program to count occurrences of a substring in a string

# %%
text = str(input("Enter your main string"))
substring = str(input("Enter your shearch "))

count = text . count(substring)

print(f"The substring {substring} {count} time is the given string")
# Out:
# The substring python 2 time is the given string

# %% [markdown]
# 3 .Write a Python program to count the occurrences of each word in a givensentence.

# %%
sentence = str(input("Enter your sentence"))

words = sentence.split()

words_count = {}

for words in words :
    words = words.lower()
    if words in words_count :
        words_count[words] += 1
    else :
        words_count[words] = 1
print("words count")
for words , count in words_count.items():
    print(words, ":", count)
# Out:
# words count
# python : 2
# is : 2
# easy : 1
# and : 1
# powerful : 1

# %% [markdown]
# 4.Write a Python program to get a single string from two given strings, separatedbya space and swap the first two characters of each string.

# %%
str_1 = str(input("Enter first words "))
str_2 = str(input("Enter secound words "))

new_str_1 = str_2[:2] + str_1[2:]
new_str_2 = str_1[:2] + str_2[2:]

result = new_str_1 + " " + new_str_2
print("result" , result)
# Out:
# result wollo  herd

# %% [markdown]
# 5 . . Write a Python program to add 'ing' at the end of a given string (length shouldbeat least 3). If the given string already ends with 'ing' then add 'ly' instead If thestring length of the given string is less than 3, leave it unchanged

# %%
word = str(input("Enter your words"))

if len(word) < 3 :
    result = word
elif word.endswith("ing"):
    result = word + " ly "
else :
    result = word + "ing"

print("result" , result)
# Out:
# result playing

# %% [markdown]
# 6 . Write a Python program to find the first appearance of the substring 'not' and'poor' from a given string, if 'not' follows the 'poor', replace the whole 'not'...'poor' substring with 'good'. Return the resulting string

# %%
def my_not_poor(s):
    not_pos =

# %% [markdown]
# 7 . Program to find Greatest Common Divisor of two numbers. For example, theGCD of 20 and 28 is 4 and the GCD of 98 and 56 is 14.

# %%
def find_gcd (x , y):
    while y != 0 :
        x , y = y , x % y
    return x 
a = int(input("Enter your number"))
b = int(input("Enter your number"))

print(f"gcd {a} and {b} is {find_gcd(a , b)}")
# Out:
# gcd 98 and 56 is 14

# %% [markdown]
# 8 .Write a Python program to check whether a list contains a sublist.

# %%
def import_sublist (main_list , sub_list):
    if not sub_list :
        return True
    if len(sub_list) > len(main_list):
        return False
    for i in range (len(main_list) - len(sub_list) + 1):
            if main_list[i:i + len(sub_list)] == sub_list:
             return True
main_list = [1, 2, 3, 4, 5]
sub_list1 = [2, 3]
sub_list2 = [3, 5]

print(is_sublist(main_list, sub_list1))
print(is_sublist(main_list, sub_list2))
# Out:
# True
# False

# %% [markdown]
# 9 . Write a Python program to find the second smallest number in a list

# %%
def secound_small (numbers):

    unique_num = sorted(set(numbers))
    if len(unique_num)< 2:
        return None 
    return unique_num [1]
    
list1 = [10 , 9 , 8 , 7 , 6 , 5]
print("list1",list1)
print("secound_small",secound_small(list1))
# Out:
# list1 [10, 9, 8, 7, 6, 5]
# secound_small 6

# %% [markdown]
# 10 . Write a Python program to get unique values from a list.

# %%
my_list = [ 1 ,2 , 3, 2, 4 , 5, 5,6,7]

unique_value = list(set(my_list))

print("orignal list",my_list)
print("unique list",unique_value)
# Out:
# orignal list [1, 2, 3, 2, 4, 5, 5, 6, 7]
# unique list [1, 2, 3, 4, 5, 6, 7]

# %% [markdown]
# 11 ..Write a Python program to unzip a list of tuples into individual lists.

# %%
data = [ (1 , "a") , (2 , "b") , (3 , "c")]

list1 , list2 = zip(*data)

list1 = list(list1)
list1 = list(list1)

print("original tuple" , data)
print("list 1" , list1)
print("list 2", list2)
# Out:
# original tuple [(1, 'a'), (2, 'b'), (3, 'c')]
# list 1 [1, 2, 3]
# list 2 ('a', 'b', 'c')

# %% [markdown]
# 12 .Write a Python program to convert a list of tuples into a dictionary

# %%
data = [ (1 , "a") , (2 , "b") , (3 , "c")]

result = dict(data)

print("orignal list of tuple",data)
print("dictionary tuple " , result)
# Out:
# orignal list of tuple [(1, 'a'), (2, 'b'), (3, 'c')]
# dictionary tuple  {1: 'a', 2: 'b', 3: 'c'}

# %% [markdown]
# 13 ..Write a Python program to sort a dictionary (ascending /descending) by value.

# %%
data = { "apple":5 ,"banana":2,"papaya":8,"watermelon":1}

asc_dict = dict(sorted(data.items(), key=lambda item: item[1]))

desc_dict =dict(sorted(data.items(), key=lambda item: item[1] , reverse=True))

print("orignan dictionary" , data)
print("ascending dictionary" , asc_dict)
print("descending  dictionary" , desc_dict)
# Out:
# orignan dictionary {'apple': 5, 'banana': 2, 'papaya': 8, 'watermelon': 1}
# ascending dictionary {'watermelon': 1, 'banana': 2, 'apple': 5, 'papaya': 8}
# descending  dictionary {'papaya': 8, 'apple': 5, 'banana': 2, 'watermelon': 1}

# %% [markdown]
# 14 .Write a Python program to find the highest 3 values in a dictionary.

# %%
my_dict = { "a": 50, "b": 20, "c": 90, "d": 10, "e": 70}

result = sorted(my_dict.values() , reverse=True)[:3]

print("orignal tuple",my_dict)
print("top3 tuple",result)
# Out:
# orignal tuple {'a': 50, 'b': 20, 'c': 90, 'd': 10, 'e': 70}
# top3 tuple [90, 70, 50]

# %% [markdown]
# 15 . Given a number n, write a python program to make and print the list of Fibonacci
# series up to n. Input : n=7 Hint : first 7 numbers in the series Expected output :
# First few Fibonacci numbers are 0, 1, 1, 2, 3, 5, 8, 13

# %%
num = 7

fib_series = [0, 1]

for i in range(2, num):
    secound_num = fib_series[i-1] + fib_series[i-2]
    fib_series.append(secound_num)

print("First few Fibonacci numbers are :",secound_num)
# Out:
# First few Fibonacci numbers are : 8

# %% [markdown]
# 16..Counting the frequencies in a list using a dictionary in Python. Input : [1, 1, 1, 5, 5, 3, 1, 3, 3, 1,4, 4, 4, 2, 2, 2, 2]
# Expected output : 1 : 5 , 2 : 4 , 3 : 3 , 4 : 3 , 5 : 2

# %%
data = [1, 1, 1, 5, 5, 3, 1, 3, 3, 1, 4, 4, 4, 2, 2, 2, 2]


def count_frequencies(lst):
    d ={}
    for item in lst :
        if item in d:
            d[item] += 1
        else :
            d[item] = 1
        return d 
result = count_frequencies(data)
    
for key , value in result.items():
    print(f"{key} : {value} " , end = " , ")
# Out:
# 1 : 1  ,

# %% [markdown]
# 17.Write a python program using function to find the sum of odd series andevenseries
# Odd series: 12/ 1! +32/ 3! + 52/ 5!+……n
# Even series: 22/ 2! + 42/ 4! + 62/ 6!+……n

# %%
import math 

def odd_series(n):
    s = 0
    for i in range (1 , n+1 , 2):
        s = s + (i ** 2) / math.factorial(i)
    return s
def even_series(n):
    s = 0
    for i in range (2 , n+1 , 2):
        s = s +(i ** 2)/ math.factorial(i)
    return s
n = int(input( " enter your n :"))

print("sum of digit" , odd_series)
print("sum of digit" , even_series)
# Out:
# sum of digit <function odd_series at 0x0000022BDE19F1A0>
# sum of digit <function even_series at 0x0000022BDE19F060>

# %% [markdown]
# 18.. Python Program to Find Factorial of Number Using Recursion

# %%
def factorial(n):
    if n == 0 or n ==1:
        return 1
    else :
        return n*factorial(n-1)

num = 5
print("factorial of" , num , "is:",factorial(num))
# Out:
# factorial of 5 is: 120

# %% [markdown]
# 19.Write a Python function that takes a list and returns a new list with unique
# elements of the first list.

# %%
def unique_list(lst):
    return list(set(lst))

numbers = [1, 2, 2, 3, 4, 4, 5, 1]
print("Original List:", numbers)
print("Unique List:", unique_list(numbers))
# Out:
# Original List: [1, 2, 2, 3, 4, 4, 5, 1]
# Unique List: [1, 2, 3, 4, 5]

# %% [markdown]
# 20 .Mini project :
# Problem Statement : Password Generator
# Make a program to generate a strong password using the input given by theuser. To generate a password, randomly take some words from the user input andtheninclude numbers, special characters and capital letters to generate the password. Also, keep a check that password length is more than 8 characters. Note: Include Exception handling wherever required. Also, make a ‘User’ classand store the details like user id, name and password of each user as a tuple.

# %%
import random
import string
class user :
    def __init__(self , user_id , Name , Password):
        self.info = (user_id , Name , Password)

    def show_info(self):
        print("user id " ,self.info[0])
        print(" Name  " ,self.info[1])
        print(" Poassword  " ,self.info[2])

class genreat_psw :
    def __init__(self , user_input):
        self.word = user_input.split()
        words = user_input.split()
        word = random.choice(words)   

        num = str(random . randint(10 , 99))
        symbol = random . choice("#!$%^&")
        capital_name = word . capitalize()

        Password = num + symbol + capital_name

        if  len(Password) <= 8 :
            Password += random . choice(string.ascii_letters + string.digits + "!@#$%^&*")
            return Password
        else :
            return f"Error:"
        
user_input = input("enter your password: ")
Password = genreat_psw(user_input)

user1 = user(1, "Tejal", Password)
print("User Details (Tuple):", user1.details)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 31
#      28             return f"Error:"
#      30 user_input = input("enter your password: ")
# ---> 31 Password = genreat_psw(user_input)
#      33 user1 = user(1, "Tejal", Password)
#      34 print("User Details (Tuple):", user1.details)
#
# TypeError: __init__() should return None, not 'str'

# %%
import random
import string


class user :
    def __init__(self , user_id , name , password):
        self.info = (user_id , name , password)

    def genreat_psw (user_input):
        if not user_input:
            raise ValueError(words)
        
        words = user_input.split()
        choise_word = random.choice(word)

        number = str(random.randint(10 , 99))
        symboll = random.choice("!#$%^&")
        capital_word =  choise_word.capitalize()

        password = number + symboll + capital_word

        while  len(password) <= 8:
            password += random.choice(string.ascii_letters + string.digits  + " !#$%^&")

        return password
# Out:
#   Cell In[7], line 5
#     def genreat_psw (user_input:)
#                                 ^
# SyntaxError: invalid syntax

# %%
import random
import string

class User:
    def __init__(self, user_id, name, password):
        self.details = (user_id, name, password)  
def generate_password(user_input):
    try:
        if not user_input:  
            raise ValueError("Input ખાલી હોઈ શકે નહિ!")

        words = user_input.split()
        chosen_word = random.choice(words)  

       
        numbers = str(random.randint(10, 99))
        special = random.choice("!@#$%^&*")
        capital_word = chosen_word.capitalize()

        password = capital_word + numbers + special

        
        while len(password) <= 8:
            password += random.choice(string.ascii_letters + string.digits + "!@#$%^&*")

        return password

    except Exception as e:
        return f"Error: {e}"
