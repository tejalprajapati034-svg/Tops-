# %% [markdown]
# 1. Install scikit-learn if you haven't already, then load the iris dataset and fit a GradientBoostingClassifier to classify the flower species. Print the model's accuracy on the test set.

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score

# Load Iris Dataset
iris = load_iris()

X = iris.data
y = iris.target

# Split Dataset
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Train Model
model = GradientBoostingClassifier(random_state=42)
model.fit(X_train, y_train)

# Prediction
y_pred = model.predict(X_test)

# Accuracy
accuracy = accuracy_score(y_test, y_pred)

print("Accuracy:", accuracy)

# %% [markdown]
# 2. Using the Flipkart product review dataset (or any small CSV with positive/negative labels), train an AdaBoostClassifier to predict if a review is positive or negative. Show the classification report (precision, recall, f1-score) for your model.<br><br><em><strong>Hint:</strong> You can use sklearn's AdaBoostClassifier and train_test_split.</em>

# %%
import pandas as pd

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import make_pipeline
from sklearn.metrics import classification_report
from sklearn.preprocessing import LabelEncoder

# Load Dataset
df = pd.read_csv("flipkart_reviews.csv")

# Features
X = df["Review"]

# Target
encoder = LabelEncoder()
y = encoder.fit_transform(df["Sentiment"])

# Split Dataset
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Pipeline
model = make_pipeline(
    CountVectorizer(),
    AdaBoostClassifier(
        estimator=DecisionTreeClassifier(max_depth=1),
        n_estimators=50,
        random_state=42
    )
)

# Train
model.fit(X_train, y_train)

# Prediction
pred = model.predict(X_test)

# Report
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       2.0
#            1       0.00      0.00      0.00       1.0
#
#     accuracy                           0.00       3.0
#    macro avg       0.00      0.00      0.00       3.0
# weighted avg       0.00      0.00      0.00       3.0

# %% [markdown]
# 3. Explain in your own words the difference between a weak learner and a strong learner, and give one real-world example of each from apps you use (like Instagram, Zomato, or Paytm).

# %% [markdown]
# #### Weak Learner (Zomato):
# - A simple decision tree may predict whether a food order will be delivered on time based only on one feature, such as distance. Since it uses limited information, its predictions may not always be accurate.
#
# #### Strong Learner (Instagram):
# - Instagram's feed recommendation system combines information such as likes, comments, shares, watch time, and user interests to recommend posts. By combining many models or weak learners, it makes highly accurate recommendations.
#
# #### Conclusion
#
# - A weak learner gives only basic predictions and may not be very accurate. A strong learner combines the knowledge of multiple weak learners to produce much more accurate and reliable predictions. This is the main idea behind boosting algorithms such as AdaBoost and Gradient Boosting.

# %% [markdown]
# 4. Modify your GradientBoostingClassifier code to tune the n_estimators and learning_rate parameters. Try at least 3 different combinations and report which one gives the best accuracy.<br><br><em><strong>Hint:</strong> n_estimators controls the number of boosting stages, learning_rate shrinks the contribution of each tree.</em>

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score

# Load Dataset
iris = load_iris()

X = iris.data
y = iris.target

# Split Dataset
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

best_accuracy = 0

for n in [50, 100, 150]:

    for lr in [0.01, 0.1, 0.5]:

        model = GradientBoostingClassifier(
            n_estimators=n,
            learning_rate=lr,
            random_state=42
        )

        model.fit(X_train, y_train)

        pred = model.predict(X_test)

        acc = accuracy_score(y_test, pred)

        print(
            "Estimators =", n,
            "Learning Rate =", lr,
            "Accuracy =", acc
        )

        if acc > best_accuracy:
            best_accuracy = acc
            best_n = n
            best_lr = lr

print("\nBest Parameters")
print("n_estimators =", best_n)
print("learning_rate =", best_lr)
print("Best Accuracy =", best_accuracy)
# Out:
# Estimators = 50 Learning Rate = 0.01 Accuracy = 1.0
# Estimators = 50 Learning Rate = 0.1 Accuracy = 1.0
# Estimators = 50 Learning Rate = 0.5 Accuracy = 1.0
# Estimators = 100 Learning Rate = 0.01 Accuracy = 1.0
# Estimators = 100 Learning Rate = 0.1 Accuracy = 1.0
# Estimators = 100 Learning Rate = 0.5 Accuracy = 1.0
# Estimators = 150 Learning Rate = 0.01 Accuracy = 1.0
# Estimators = 150 Learning Rate = 0.1 Accuracy = 1.0
# Estimators = 150 Learning Rate = 0.5 Accuracy = 1.0
#
# Best Parameters
# n_estimators = 50
# learning_rate = 0.01
# Best Accuracy = 1.0

# %% [markdown]
# 5. Find a real-world use case of boosting in a popular Indian app (such as fraud detection in Paytm or spam filter in WhatsApp). Write 3-4 lines describing how boosting could improve the app's performance.

# %% [markdown]
# ### Example: Paytm Fraud Detection
#
# #### Answer:
#
# - Boosting can be used in Paytm to detect fraudulent transactions. Multiple weak models are combined to create a strong model that can identify suspicious payment patterns more accurately. This reduces false alarms and improves the detection of genuine fraud. As a result, users experience more secure and reliable digital payments.
