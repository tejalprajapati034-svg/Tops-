# %% [markdown]
# 1. Given two 2x2 matrices representing the number of likes and comments on two Instagram posts over two days, write Python code to multiply them and display the resulting matrix.

# %%
# Matrix A = Likes
likes = [
    [100, 120],
    [150, 180]
]

# Matrix B = Comments
comments = [
    [20, 25],
    [30, 35]
]

# Result matrix
result = [[0, 0], [0, 0]]

# Matrix multiplication
for i in range(2):
    for j in range(2):
        for k in range(2):
            result[i][j] += likes[i][k] * comments[k][j]

print("Likes Matrix:")
for row in likes:
    print(row)

print("\nComments Matrix:")
for row in comments:
    print(row)

print("\nResult of Matrix Multiplication:")
for row in result:
    print(row)
# Out:
# Likes Matrix:
# [100, 120]
# [150, 180]
#
# Comments Matrix:
# [20, 25]
# [30, 35]
#
# Result of Matrix Multiplication:
# [5600, 6700]
# [8400, 10050]

# %% [markdown]
# 2. Create a simple Python function linear_regression_predict(x, m, c) that takes an input value x, slope m, and intercept c, and returns the predicted output y for a linear regression equation y = mx + c.

# %%
def linear_regression_predict(x, m, c):
    y = m * x + c
    return y

# Example
print(linear_regression_predict(5, 4, 10))
# Out:
# 30

# %% [markdown]
# 3. Imagine you are predicting the delivery time for Zomato orders based on distance. Given three distances (2km, 5km, 8km) and a linear regression equation y = 4x + 10 (where y is minutes), use your function from the previous task to calculate the predicted delivery time for each distance.

# %%
def linear_regression_predict(x, m, c):
    return m * x + c

# Equation: y = 4x + 10
m = 4
c = 10

distances = [2, 5, 8]

print("Predicted Delivery Times:\n")

for distance in distances:
    time = linear_regression_predict(distance, m, c)
    print(f"Distance: {distance} km --> Delivery Time: {time} minutes")
# Out:
# Predicted Delivery Times:
#
# Distance: 2 km --> Delivery Time: 18 minutes
# Distance: 5 km --> Delivery Time: 30 minutes
# Distance: 8 km --> Delivery Time: 42 minutes

# %% [markdown]
# 4. Explain in your own words what the slope and intercept represent in the context of Flipkart's product price prediction (e.g., predicting price based on product rating). Write 2-3 sentences for each term.

# %% [markdown]
# #### Slope
#
# - The slope shows how much the predicted product price changes when the product rating increases by one unit. For example, if the slope is ₹500, then increasing the rating by one point increases the predicted price by ₹500.
#
# #### Intercept
#
# - The intercept is the predicted product price when the rating is 0. Although a rating of 0 may not occur in practice, the intercept provides the starting value for the linear regression equation.

# %% [markdown]
# 5. Use ChatGPT to ask: 'How does matrix multiplication help in training a machine learning model like Spotify's song recommendation system?' Summarize the answer in your own words in 3-4 sentences.

# %% [markdown]
# - Matrix multiplication helps combine user preferences with song features to calculate recommendation scores efficiently. It allows machine learning models to process large amounts of data quickly by performing many calculations at the same time. During training, it is used to update model weights and improve prediction accuracy. This makes personalized song recommendations faster and more accurate for each user.
