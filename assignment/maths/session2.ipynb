# %% [markdown]
# 1. Create a Python script called playlist_stats.py that takes a list of daily Spotify song play counts (e.g., [120, 135, 150, 200, 120, 90, 200]) and calculates the mean (average) number of plays.

# %%
# playlist_stats.py

import statistics

# Daily Spotify song play counts
play_counts = [120, 135, 150, 200, 120, 90, 200]

# Calculate mean
mean_plays = statistics.mean(play_counts)

print("Daily Play Counts:", play_counts)
print("Mean (Average) Plays:", mean_plays)
# Out:
# Daily Play Counts: [120, 135, 150, 200, 120, 90, 200]
# Mean (Average) Plays: 145

# %% [markdown]
# 2. Given the following array of delivery times (in minutes) for Zomato orders: [30, 25, 40, 35, 30, 45, 30], write code to find the median delivery time and print it.

# %%
import statistics

delivery_times = [30, 25, 40, 35, 30, 45, 30]

median_time = statistics.median(delivery_times)

print("Delivery Times:", delivery_times)
print("Median Delivery Time:", median_time)
# Out:
# Delivery Times: [30, 25, 40, 35, 30, 45, 30]
# Median Delivery Time: 30

# %% [markdown]
# 3. Write a function most_common_rating(ratings) that takes a list of Flipkart product ratings (e.g., [5, 4, 4, 3, 5, 4, 2, 4]) and returns the mode (most frequent rating).

# %%
import statistics

def most_common_rating(ratings):
    return statistics.mode(ratings)

ratings = [5, 4, 4, 3, 5, 4, 2, 4]

print("Ratings:", ratings)
print("Most Common Rating:", most_common_rating(ratings))
# Out:
# Ratings: [5, 4, 4, 3, 5, 4, 2, 4]
# Most Common Rating: 4

# %% [markdown]
# 4. Given three lists representing YouTube video views for three different channels, compare the mean, median, and mode for each channel, and decide which channel's data is most affected by outliers.<br><br><em><strong>Hint:</strong> Try using one list with a very high value (e.g., [100, 120, 110, 105, 5000]) to see the effect on mean vs median.</em>

# %%
import statistics

channel1 = [100, 120, 110, 105, 115]
channel2 = [200, 220, 210, 205, 215]
channel3 = [100, 120, 110, 105, 5000]  # Outlier


def analyze_channel(name, views):
    print(f"\n{name}")
    print("Views:", views)
    print("Mean:", statistics.mean(views))
    print("Median:", statistics.median(views))
    print("Mode:", statistics.mode(views))


analyze_channel("Channel 1", channel1)
analyze_channel("Channel 2", channel2)
analyze_channel("Channel 3", channel3)

print("\nConclusion:")
print("Channel 3 is most affected by the outlier (5000).")
print("The mean increases significantly, while the median remains close to the typical values.")
# Out:
# Channel 1
# Views: [100, 120, 110, 105, 115]
# Mean: 110
# Median: 110
# Mode: 100
#
# Channel 2
# Views: [200, 220, 210, 205, 215]
# Mean: 210
# Median: 210
# Mode: 200
#
# Channel 3
# Views: [100, 120, 110, 105, 5000]
# Mean: 1087
# Median: 110
# Mode: 100
#
# Conclusion:
# Channel 3 is most affected by the outlier (5000).
# The mean increases significantly, while the median remains close to the typical values.

# %% [markdown]
# 5. Pick any real dataset from Kaggle or UCI (e.g., IPL player runs, Swiggy restaurant ratings, or movie box office collections), load it using pandas, and display the mean, median, and mode for one numeric column of your choic

# %%
import pandas as pd

# Load dataset
df = pd.read_csv("zomato.csv")

# Display first few rows
print(df.head())

# Numeric column
column = "votes  "

print("\nMean:", df["average_cost_for_two"].mean())
print("Median:", df["votes"].median())
print("Mode:")
print(df["votes"].mode())
# Out:
#    rating  votes  online_order  table_booking  average_cost_for_two
# 0     4.5   2500             1              1                  1200
# 1     4.1    900             1              0                   700
# 2     3.9    650             0              0                   500
# 3     4.8   3500             1              1                  1800
# 4     4.2   1400             1              0                   900
#
# Mean: 920.0
# Median: 1150.0
# Mode:
# 0     400
# 1     500
# 2     650
# 3     850
# 4     900
# 5    1400
# 6    2200
# 7    2500
# 8    2800
# 9    3500
# Name: votes, dtype: int64
