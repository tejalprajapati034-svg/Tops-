# %% [markdown]
# 1. Write down the null hypothesis (H0) and alternative hypothesis (H1) for the following scenario: You believe that people spend more time on Instagram than on YouTube daily.

# %% [markdown]
# #### null Hypothesis(H₀):
# - Hypothesis is a statical method to cheack if a claim about a population is true using sample data
# - a statement that there is no difference , no effect , or no change
# - People spend the same amount of time or less time on Instagram than on YouTube daily.
# H0​: μInstagram​≤μYouTube​
#
# #### Altenative Hypothesis :
# - is a claim that somthing is heppening
# - People spend more time on Instagram than on YouTube daily.
# H1​: μInstagram​>μYouTube​

# %% [markdown]
# 2. Given the data: Group A (users shown a new Zomato home page) had an average order value of ₹350 from 30 users, and Group B (old home page) had an average order value of ₹320 from 30 users. Assume both groups have a standard deviation of ₹50. Calculate the p-value using a two-sample t-test (you may use Python, R, or an online calculator), and decide whether to accept or reject the null hypothesis at a 0.05 significance level.<br><br><em><strong>Hint:</strong> Use scipy.stats.ttest_ind in Python or any online t-test calculator if you are not comfortable with code.</em>

# %%
from scipy.stats import ttest_ind_from_stats

# Group statistics
mean1 = 350
std1 = 50
n1 = 30

mean2 = 320
std2 = 50
n2 = 30

t_stat, p_value = ttest_ind_from_stats(
    mean1=mean1, std1=std1, nobs1=n1,
    mean2=mean2, std2=std2, nobs2=n2,
    equal_var=True
)

print("T-Statistic:", round(t_stat, 4))
print("P-Value:", round(p_value, 4))

if p_value < 0.05:
    print("Reject the Null Hypothesis")
else:
    print("Fail to Reject the Null Hypothesis")
# Out:
# T-Statistic: 2.3238
# P-Value: 0.0237
# Reject the Null Hypothesis

# %% [markdown]
# 3. Pick any feature from your favorite app (like the new dark mode in WhatsApp or a redesigned payment button in Paytm) and describe how you would set up an A/B test for it. Clearly state what your control and variant groups would be, what metric you would measure, and what your null and alternative hypotheses are.

# %% [markdown]
# #### A/B Test Example
#
# #### Feature: WhatsApp Dark Mode
#
# - Control Group (A): Users with the old light mode.
# - Variant Group (B): Users with the new dark mode.
# - Metric: Average daily time spent on WhatsApp.
# - Null Hypothesis (H₀): Dark mode does not change the average daily usage time.
# - Alternative Hypothesis (H₁): Dark mode increases the average daily usage time.

# %% [markdown]
# 4. Suppose you run an A/B test for a new 'Add to Wishlist' button design on Flipkart. Out of 1000 users, 520 clicked the new button versus 480 who clicked the old button. Without doing detailed calculations, explain if this difference is likely to be significant or just due to chance. Briefly explain how the p-value helps you decide.

# %% [markdown]
# - Old Button Clicks = 480 / 1000
# - New Button Clicks = 520 / 1000
#
# - The new button received 40 more clicks than the old one. This difference may be statistically significant, but we cannot be certain without calculating the p-value.
#
# - The p-value tells us whether the observed difference is likely due to random chance. If the p-value is less than 0.05, we conclude that the new button performs significantly better. If it is greater than 0.05, the difference may simply be due to chance.
