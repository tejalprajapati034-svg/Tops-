# %% [markdown]
# 1. Given a list of delivery timestamps as strings (e.g., ['2024-06-01 14:30', '2024-06-02 09:15', '2024-06-03 20:45']), use pandas and pd.to_datetime() to convert them into datetime objects and print the result.

# %%
import pandas as pd

delivery_times = [
    '2024-06-01 14:30',
    '2024-06-02 09:15',
    '2024-06-03 20:45'
]

datetime_series = pd.to_datetime(delivery_times)

print("Datetime Objects:")
print(datetime_series)
# Out:
# Datetime Objects:
# DatetimeIndex(['2024-06-01 14:30:00', '2024-06-02 09:15:00',
#                '2024-06-03 20:45:00'],
#               dtype='datetime64[ns]', freq=None)

# %% [markdown]
# 2. Load a CSV file containing order dates from a Flipkart-style order history (column: 'order_date', format: 'YYYY-MM-DD HH:MM:SS'). Extract the year, month, and weekday for each order and add them as new columns in the DataFrame.

# %%
import pandas as pd

df = pd.read_csv("flipkart_orders.csv")

df["order_date"] = pd.to_datetime(df["order_date"])

df["year"] = df["order_date"].dt.year
df["month"] = df["order_date"].dt.month
df["weekday"] = df["order_date"].dt.day_name()

print(df)
# Out:
#    order_id          order_date  amount  year  month   weekday
# 0       101 2024-06-01 14:30:00    1200  2024      6  Saturday
# 1       102 2024-06-03 10:15:00     850  2024      6    Monday
# 2       103 2024-06-08 18:45:00     950  2024      6  Saturday
# 3       104 2024-06-10 09:20:00    1500  2024      6    Monday
# 4       105 2024-06-15 20:00:00     650  2024      6  Saturday

# %% [markdown]
# 3. Set the 'order_date' column as the index of your DataFrame and use resampling to calculate the total number of orders placed each week.<br><br><em><strong>Hint:</strong> Use df.resample('W').size() after setting the datetime index.</em>

# %%
import pandas as pd

df = pd.read_csv("flipkart_orders.csv")

df["order_date"] = pd.to_datetime(df["order_date"])

df.set_index("order_date", inplace=True)

weekly_orders = df.resample("W").size()

print("Weekly Orders:")
print(weekly_orders)
# Out:
# Weekly Orders:
# order_date
# 2024-06-02    1
# 2024-06-09    2
# 2024-06-16    2
# Freq: W-SUN, dtype: int64

# %% [markdown]
# 4. Suppose you have a DataFrame of Instagram posts with a 'posted_at' column in UTC. Convert these timestamps to 'Asia/Kolkata' timezone and display the first 5 converted times.

# %%
import pandas as pd

posts = pd.DataFrame({
    "post_id": [1,2,3,4,5],
    "posted_at": [
        "2024-06-01 08:00:00",
        "2024-06-02 10:30:00",
        "2024-06-03 12:15:00",
        "2024-06-04 15:45:00",
        "2024-06-05 18:20:00"
    ]
})

posts["posted_at"] = pd.to_datetime(posts["posted_at"], utc=True)


posts["posted_at"] = posts["posted_at"].dt.tz_convert("Asia/Kolkata")

print(posts.head())
# Out:
#    post_id                 posted_at
# 0        1 2024-06-01 13:30:00+05:30
# 1        2 2024-06-02 16:00:00+05:30
# 2        3 2024-06-03 17:45:00+05:30
# 3        4 2024-06-04 21:15:00+05:30
# 4        5 2024-06-05 23:50:00+05:30

# %% [markdown]
# 5. Create a new feature called 'is_weekend' in your DataFrame that marks True if an order was placed on Saturday or Sunday, and False otherwise.<br><br><em><strong>Constraint:</strong> Do not use any external libraries except pandas and numpy.</em>

# %%
import pandas as pd

df = pd.read_csv("flipkart_orders.csv")

df["order_date"] = pd.to_datetime(df["order_date"])

df["is_weekend"] = df["order_date"].dt.dayofweek >= 5

print(df)
# Out:
#    order_id          order_date  amount  is_weekend
# 0       101 2024-06-01 14:30:00    1200        True
# 1       102 2024-06-03 10:15:00     850       False
# 2       103 2024-06-08 18:45:00     950        True
# 3       104 2024-06-10 09:20:00    1500       False
# 4       105 2024-06-15 20:00:00     650        True
