# %% [markdown]
# ## 1.Explain Key Statistical Concepts

# %% [markdown]
# Mean (Average)
#
# Definition:
# The mean is the sum of all values divided by the number of values.
#
# Formula:
#
#  Mean
# =
# ∑
# 𝑥
# 𝑛
#   Mean=
# n
# ∑x
# 	​
#
#
# Example:
# Values: 10, 20, 30
# Mean = (10 + 20 + 30) / 3 = 20

# %% [markdown]
# Median
#
# Definition:
# The median is the middle value when data is arranged in order.
#
# Example:
# Values: 10, 20, 30 → Median = 20
# Values: 10, 20, 30, 40 → Median = (20 + 30)/2 = 25

# %% [markdown]
# Mode
#
# Definition:
# The value that appears most frequently.
#
# Example:
# Values: 2, 4, 4, 6 → Mode = 4

# %% [markdown]
# Range
#
# Definition:
# Difference between maximum and minimum values.
#
# Formula:
#
# Range
# =
# Max
# −
# Min
# Range=Max−Min
#
# Example:
# Values: 5, 15, 25 → Range = 25 − 5 = 20

# %% [markdown]
# Variance
#
# Definition:
# Measures how far data points are spread from the mean.
#
#
# Standard Deviation
#
# Definition:
# Square root of variance; shows average deviation from the mean.
#
#
# Correlation
#
# Definition:
# Measures the relationship between two variables.
#
# Values:
#
# +1 → Strong positive correlation
#
# 0 → No correlation
#
# −1 → Strong negative correlation
#
# Probability
#
# Definition:
# Chance of an event occurring.
#
# Formula:
#
# 𝑃
# (
# 𝐸
# )
# =
# Favorable outcomes
# Total outcomes
# P(E)=
# Total outcomes
# Favorable outcomes
# 	​
# Normal Distribution
#
# Definition:
# A symmetric, bell-shaped distribution.
#
# Outliers
#
# Definition:
# Values that are significantly different from others.
#
# Skewness
#
# Definition:
# Measures asymmetry of data distribution
#
# Confidence Interval
#
# Definition:
# A range within which the true population parameter lies.
#
# Hypothesis Testing
#
# Definition:
# A method to test assumptions about data.

# %% [markdown]
# ## Presentation: Importance of Probability in Machine Learning

# %%
import numpy as np 
from scipy import stats

# %%
# 1. Business Problem: A car rental company wants to analyze the rental durations of its customers
#to understand the typical rental period and optimize its pricing andfleet
#management strategies. Data: Let's consider the rental durations (in days) for asample of 50 customers:

a = np.array([3, 2, 5, 4, 7, 2, 3, 3, 1, 6, 4, 2, 3, 5, 2, 4, 2, 1, 3, 5, 6, 3, 2, 1
, 4, 2, 4, 5, 3, 2, 7, 2, 3, 4, 5, 1, 6, 2, 4, 3, 5, 3, 2, 4, 2, 6, 3, 2, 4, 5])

# %%
mean = np.mean(a)
median = np.median(a)
mode = stats.mode(a)

mean , median , mode
# Out:
# (np.float64(3.44),
#  np.float64(3.0),
#  ModeResult(mode=np.int64(2), count=np.int64(13)))

# %%
# 2An e-commerce platform wants to analyze the delivery times of its shipments tounderstand the 
# variability in order fulfillment and optimize its logistics operations.

data = np.array([3, 5, 2, 4, 6, 2, 3, 4, 2, 5, 7, 2, 3, 4, 2, 4, 2, 3, 5, 6, 3, 2, 1, 4, 2,
                 4, 5, 3, 2, 7, 2, 3, 4, 5, 1, 6, 2, 4, 3, 5, 3, 2, 4, 2, 6, 3, 2, 4, 5, 3])

# %%
range = np.max(data)-np.min(data)
variance = np.var(data, ddof = 1)
Standard_Deviation = np.std(data , ddof =1)

range , variance , Standard_Deviation
# Out:
# (np.int64(6), np.float64(2.336326530612245), np.float64(1.528504671439458))

# %%
# 3. A company wants to analyze the 
# monthly revenue generated by one of its productsto understand its performance and variability

revenue = np.array([120, 150, 110, 135, 125, 140, 130, 155, 115, 145, 135, 130])

# %%
revenue_mean = np.mean(revenue)

revenue_mean
# Out:
# np.float64(132.5)

# %%
revenue_range = np.max(revenue) - np.min(revenue)

revenue_range
# Out:
# np.int64(45)

# %%
# 4.A transportation company wants to analyze the fuel efficiency of its vehicle
#  fleet toidentify any variations across different vehicle models.

Model_A = np.array([30, 32, 33, 28, 31, 30, 29, 30, 32, 31])
Model_B = np.array([25, 27, 26, 23, 28, 24, 26, 25, 27, 28])
Model_C = np.array([22, 23, 20, 25, 21, 24, 23, 22, 25, 24])
Model_D = np.array([18, 17, 19, 20, 21, 18, 19, 17, 20, 19])
Model_E = np.array([35, 36, 34, 35, 33, 34, 32, 33, 36, 34])

# %%
# for model A
range_A = np.max(Model_A) - np.min(Model_A)
variance_A = np.var(Model_A, ddof = 1)
mean_A = np.mean(Model_A)

range_A, variance_A, mean_A
# Out:
# (np.int64(5), np.float64(2.2666666666666675), np.float64(30.6))

# %%
# for model B
range_B = np.max(Model_B) - np.min(Model_B)
variance_B = np.var(Model_B , ddof = 1)
mean_B = np.mean(Model_B)

range_B ,variance_B ,mean_B
# Out:
# (np.int64(5), np.float64(2.766666666666667), np.float64(25.9))

# %%
# for model C 
range_C = np.max(Model_C) - np.min(Model_C)
variance_C = np.var(Model_C , ddof = 1)
mean_C = np.mean(Model_C)

range_C , variance_C , mean_C
# Out:
# (np.int64(5), np.float64(2.7666666666666666), np.float64(22.9))

# %%
# for model D 
range_D = np.max(Model_D) - np.min(Model_D)
variance_D = np.var(Model_D , ddof=1)
mean_D = np.mean(Model_D)

range_D , variance_D , mean_D
# Out:
# (np.int64(4), np.float64(1.7333333333333334), np.float64(18.8))

# %%
# for model E
range_E = np.max(Model_E) - np.min(Model_E)
variance_E = np.var(Model_E , ddof=1)
mean_E = np.mean(Model_E)

range_E , variance_E ,mean_E
# Out:
# (np.int64(4), np.float64(1.7333333333333332), np.float64(34.2))

# %%
# 5. A manufacturing company wants to analyze the defect rates of its
# production line to identify the frequency of different types of defects.
#Data: Let's consider the types of defects and their corresponding frequencies observed in a sample of 200 products:
Defect_Type = ['A', 'B', 'C', 'D', 'E', 'F', 'G']
Frequency = np.array ([30, 40, 20, 10, 45, 25, 30])

# %%
# a. Bar Chart: Create a bar chart to visualize the frequency of different defect types.
import matplotlib.pyplot as plt
plt.bar(Defect_Type, Frequency)
plt.xlabel('Defect Type')
plt.ylabel('Frequency')
plt.title('Frequency of Different Defect Types')
plt.show()

# %%
# b. Most Common Defect: Which defect type has the highest frequency?
most_common_defect = Defect_Type[np.argmax(Frequency)]
print("The defect type with the highest frequency is:" ,most_common_defect )
# Out:
# The defect type with the highest frequency is: E

# %%
# c. Histogram: Create a histogram to represent the defect frequencies
plt.hist(Frequency, bins = 6, edgecolor = 'black')
plt.title('Histogram of Defect Frequencies')
plt.show()

# %%
# 6. A survey was conducted to analyze the satisfaction ratings of customers onascaleof 1 to 5 for a specific product.
#Data: Let's consider the satisfaction ratings from 200 customers:
Ratings = np.array([4, 5, 3, 4, 4, 3, 2, 5, 4, 3, 5, 4, 2, 3, 4, 5, 3, 4, 5, 3,
                    4, 3, 2, 4, 5, 3, 4, 5, 4, 3, 3, 4, 5, 2, 3, 4, 4, 3, 5, 4,
                    3, 4, 5, 4, 2, 3, 4, 5, 3, 4, 5, 4, 3, 4, 5, 3, 4, 5, 4, 3,
                    3, 4, 5, 2, 3, 4, 4, 3, 5, 4, 3, 4, 5, 4, 2, 3, 4, 5, 3, 4,
                    5, 4, 3, 4, 5, 3, 4, 5, 4, 3, 3, 4, 5, 2, 3, 4, 4, 3, 5, 4])

# %%
# a. Skewness: Calculate the skewness of the satisfaction ratings
skewness = stats.skew(Ratings)
print("The skewness of the satisfaction ratings is:",skewness)
# Out:
# The skewness of the satisfaction ratings is: -0.20773281879682218

# %%
#b. Kurtosis: Calculate the kurtosis of the satisfaction ratings.
Kurtosis = stats.kurtosis(Ratings)
print("The kurtosis of the satisfaction ratings is:" ,Kurtosis )
# Out:
# The kurtosis of the satisfaction ratings is: -0.767917404014467

# %%
# c. Interpretation: Based on the skewness and kurtosis values, 
# what can be inferred about the satisfaction ratings distribution?

if skewness > 0:
    print("The satisfaction ratings are positively skewed.")
elif skewness < 0:
    print("The satisfaction ratings are negatively skewed.")
else:
    print("The satisfaction ratings are symmetric.")
# Out:
# The satisfaction ratings are negatively skewed.

# %%
#7. A research study wants to analyze the weight distribution of a sample of individuals to assess their health and body composition.
# Data: Let's consider the weights (in kilograms) of a sample of 100 individuals:
Weights = np.array([55, 60, 62, 65, 68, 70, 72, 75, 78, 80,82, 85, 88, 90, 92,
                    95, 100, 105, 110, 115,120, 125, 130, 135, 140, 145, 150,
                    155, 160, 165, 170, 175, 180, 185, 190, 195, 200, 205,
                    210, 215, 220, 225, 230, 235, 240, 245, 250,255, 260,
                    265, 270, 275, 280, 285, 290, 295, 300, 305, 310, 315,
                    320, 325, 330, 335, 340,345, 350, 355, 360, 365, 370,
                    375, 380, 385, 390, 395, 400, 405, 410, 415, 420, 425,
                    430, 435, 440, 445, 450, 455, 460, 465, 470, 475,
                    480, 485, 490, 495, 500, 505, 510, 515])

# %%
# a. Quartiles: Calculate the first quartile (Q1), median (Q2), and 
# thirdquartile(Q3) of the weight distribution.

Q1 = np.quantile(Weights ,0.25)
Q2 = np.quantile(Weights ,0.5)
Q3 = np.quantile(Weights ,0.75)

print("Q1 =" , Q1 )
print("Q2 =" , Q2)
print("Q3 =" , Q3 )
# Out:
# Q1 = 143.75
# Q2 = 267.5
# Q3 = 391.25

# %%
# b. Percentiles: Calculate the 15th percentile,
#  50th percentile, and 85thpercentile of the weight distribution.

Percentile_15 = np.percentile(Weights, 15)
Percentile_50 = np.percentile(Weights, 50)
Percentile_85 = np.percentile(Weights, 85)

print(" percentile_15 =" ,percentile_15)
print("percentile_50 =" , Percentile_50)
print("percentile_85 =" ,Percentile_85)
# Out:
#  percentile_15 = 94.55
# percentile_50 = 267.5
# percentile_85 = 440.74999999999994

# %%
# c. Interpretation: Based on the quartiles and percentiles, 
# what can be inferredabout the weight distribution of the individuals?

if Q1 < Q2 < Q3:
    print("The weight distribution is positively skewed.")
elif Q1 > Q2 > Q3:
    print("The weight distribution is negative  skewed.")
else :
    print("The weight distribution is symmetric.")
# Out:
# The weight distribution is positively skewed.

# %%
# 8. A researcher wants to examine the relationship between the hours spent studying and the exam scores of a group of students.
#Data: Let's consider the number of hours spent studying and the correspondingexam scores for a sample of 30 students:
Hours_of_Studying = ([10, 12, 15, 18, 20, 22, 25, 28, 30, 32, 35, 38, 40, 42, 45, 48, 50, 52, 55, 58, 60, 62, 65, 68,
                      70, 72, 75, 78, 80, 82])
Exam_Scores = ([60, 65, 70, 75, 80, 82, 85, 88, 90, 92, 93, 95, 96, 97, 98,
                      99, 100, 102, 105, 106, 107, 108, 110, 112, 114, 115, 116, 118, 120, 122])

# %%
# Calculate the correlation coefficient between the hours spent studying andtheexam scores. Interpret the value of the
#correlation coefficient and explain the nature of the relationship between studying hours and examscores.
correlation_coefficient = np.corrcoef(Hours_of_Studying , Exam_Scores)[0 ,1]
correlation_coefficient
# Out:
# np.float64(0.9772950830186736)

# %% [markdown]
# ### **so, here we can say that there is a strong relationship between studying hours and examscores**

# %%
#9. A multiple-choice test consists of 10 questions, each with four possible answers. If astudent randomly guesses on each question,
# what is the probability of gettingat least 8 questions correct?
#Data: Number of questions (n) = 10, Number of possible answers per question (k) = 4

n = 10
p = 1/4

probablity = stats .binom.pmf(8 , n , p) + stats .binom.pmf(9 , n , p) + stats .binom.pmf(19 , n , p)

print("probability" ,probablity)
# Out:
# probability 0.00041484832763671886

# %%
# 10.The lifetimes of a certain brand of light bulbs are normally distributed with a mean of 1000 hours and a standard deviation of 100 hours.
#What is the probability that a randomly selected light bulb lasts between 900 and 1100 hours?
#Data: Meanlifetime(μ) = 1000 hours, Standard deviation (σ) = 100 hours, Lifetime range (lower limit x1, upper limit x2)

mu = 1000
sigma = 100
x1 = 900
x2 = 1100
z1 = (x1 - mu) / sigma
z2 = (x2 - mu) / sigma
probability = stats.norm.cdf(z2) - stats.norm.cdf(z1)

print(probability)
# Out:
# 0.6826894921370859

# %%
import numpy as np
from scipy import stats

# Given data
n = 100
x_bar = 170
standard_deviation = 8
confidence_level = 0.95

# Standard Error
standard_error = standard_deviation / np.sqrt(n)

# Z-score for 95% confidence
z_score = stats.norm.ppf(1 - (1 - confidence_level) / 2)

# Margin of Error
margin_of_error = z_score * standard_error

# Confidence Interval
lower_limit = x_bar - margin_of_error
upper_limit = x_bar + margin_of_error

lower_limit, upper_limit
# Out:
# (np.float64(168.43202881236795), np.float64(171.56797118763205))

# %%
# 12. A manufacturing company claims that the average weight of its product is 500grams. To test this claim,
# a random sample of 25 products is selected, and their weights are measured. The sample mean weight is found
# to be 510 grams with a sample standard deviation of 20 grams. Perform a hypothesis test to determine if
# there is evidence to support the company's claim.
# Data: Sample size (n) =25, Sample mean (x̄) = 510 grams, Sample standard deviation (s) = 20 grams, Population mean (μ) = 500 grams

# %%
n = 25 
x_bar = 510
s = 20 
mu = 500

t_stats = (x_bar - mu) / (s / np.sqrt(n))

df = n -1

p_value = 2* (1-stats.t.cdf(np.abs(t_stats), df))

alpha = 0.05

if p_value < alpha :
 print('Reject the null hypothesis')
else :
 print('Fail to reject the null hypothesis')
# Out:
# Reject the null hypothesis

# %%
# 13.A researcher wants to test whether a new teaching method improves student performance. A random sample of 50 students is divided into two groups: one group taught using the new method
# and the other using the traditional method. The average test scores of the two groups are compared. State the null and alternative hypotheses for this study.
#Data: Sample size (n) = 50, Test scores of the two groups

import numpy as np
import scipy.stats as stats
n = 50
new_method_scores = np.array([85, 88, 90, 82, 87, 89, 91, 84, 86, 88, 92,
                              85, 88, 90, 86, 87, 85, 91, 89, 88, 87,
                              90, 86, 88, 85,])
traditional_method_scores = np.array([78, 80, 82, 75, 79, 81, 83, 76, 78, 80,
                                      84, 77, 80, 82, 79, 80, 78, 83, 81, 80,
                                      79, 82, 78, 80, 77])

t_stat, p_value = stats.ttest_ind(new_method_scores, traditional_method_scores , alternative='greater')

print("t-statistic:", t_stat)
print("p-value:", p_value)
# Out:
# t-statistic: 11.677833155539052
# p-value: 6.217669798039453e-16

# %%
# 14. A survey is conducted to estimate the proportion of people in a city who support aparticular policy.
#A random sample of 500 individuals is surveyed, and 320 of them express support for the policy. Calculate a 90% confidence interval for the population proportion, given the sample proportion.
# Data: Sample size (n) =500, Number of successes (x) = 320, Confidence level = 90%

n = 500
x_bar = 320
Confidencelevel = 0.90

p = x_bar / n

standerd_error = np.sqrt((p))
# Out:
# 0.64

# %%
# 15.A company sells smartphones, and the number of defects per batch follows a Poisson distribution with a mean of 2 defects.
# What is the probability of havingexactly 3 defects in a randomly selected batch?
# Data: Mean number of defects (λ) =2, Number of defects (x) = 3

lambda_val = 2
x_bar = 3
probability = stats.poisson.pmf(x_bar, lambda_val)

print("The probability of having exactly {x} defects in a batch with a mean of {lambda_val} is: {probability:.4f}")
# Out:
# The probability of having exactly {x} defects in a batch with a mean of {lambda_val} is: {probability:.4f}
